# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly as py
import plotly.graph_objs as go
import plotly.express as px
import ipywidgets as widgets

# %%
df = pd.read_csv('cut_df.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#              LoanRange                              BusinessName  \
# 0      a $5-10 million     ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1      a $5-10 million                     CRUZ CONSTRUCTION INC
# 2      a $5-10 million                    I. C. E. SERVICES, INC
# 3      a $5-10 million                KATMAI HEALTH SERVICES LLC
# 4      a $5-10 million           MATANUSKA TELEPHONE ASSOCIATION
# ...                ...                                       ...
# 26444   b $2-5 million                CONSOLIDATED ANALYTICS INC
# 26445   b $2-5 million  CONSTRUCTION TESTING SERVICES, A CALIFOR
# 26446   b $2-5 million                        CONSUMERTRACK,INC.
# 26447   b $2-5 million             CONTRACT SERVICES GROUP, INC.
# 26448   b $2-5 million                 CONTRACTORS WARDROBE INC.
#
#                                       Address        City State      Zip  \
# 0                                7000 Uula St      BARROW    AK  99723.0
# ...

# %%
df['NAICSCode'].describe
# Out:
# <bound method NDFrame.describe of 0        813920.0
# 1        238190.0
# 2        722310.0
# 3        621111.0
# 4        517311.0
#            ...
# 26444    531390.0
# 26445    238990.0
# 26446    541890.0
# 26447    541990.0
# 26448    332999.0
# Name: NAICSCode, Length: 26449, dtype: float64>

# %%
df['NAICSCode'].fillna(0, inplace=True)

# %%
df['Zip'] = df['Zip'].astype(int)
df['Zip'] = df['Zip'].astype(int)
df['NAICSCode'] = df['NAICSCode'].astype(int)
df['DateApproved']= pd.to_datetime(df['DateApproved'])

# %% [markdown]
# Ranges for Salary:
#
#     a = 5M - 10M -- 5M
#     b = 2M - 4.9M -- 2M
#     c = 1M - 1.9M -- 1M
#     d = 350,000 - 999,999 -- 350k
#     e = 150,000 - 349,999 -- 150k

# %%
df.LoanRange = df['LoanRange'].str.replace(' ', '',)

# %%
df.LoanRange = df['LoanRange'].str.replace('a', '')
df.LoanRange = df['LoanRange'].str.replace('b', '')
df.LoanRange = df['LoanRange'].str.replace('c', '')
df.LoanRange = df['LoanRange'].str.replace('d', '')
df.LoanRange = df['LoanRange'].str.replace('e', '')

# %%
df.LoanRange = df.LoanRange.astype('category')
df.BusinessType = df.BusinessType.astype('category')

# %%
df
# Out:
#           LoanRange                              BusinessName  \
# 0      $5-10million     ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1      $5-10million                     CRUZ CONSTRUCTION INC
# 2      $5-10million                    I. C. E. SERVICES, INC
# 3      $5-10million                KATMAI HEALTH SERVICES LLC
# 4      $5-10million           MATANUSKA TELEPHONE ASSOCIATION
# ...             ...                                       ...
# 26444   $2-5million                CONSOLIDATED ANALYTICS INC
# 26445   $2-5million  CONSTRUCTION TESTING SERVICES, A CALIFOR
# 26446   $2-5million                        CONSUMERTRACK,INC.
# 26447   $2-5million             CONTRACT SERVICES GROUP, INC.
# 26448   $2-5million                 CONTRACTORS WARDROBE INC.
#
#                                       Address        City State    Zip  \
# 0                                7000 Uula St      BARROW    AK  99723
# 1                7000 East Palmer Wasilla Hwy      PALMER    AK  99645
# ...

# %%
import plotly.express as px
pd.options.plotting.backend = "plotly"

# %%
fig = px.bar(df, x="LoanRange", y="JobsRetained", title="Long-Form Input")
fig.show()
# Out:
# <div>
#
#
#             <div id="9cc35119-f664-40c9-b853-ea0198219d74" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9cc35119-f664-40c9-b853-ea0198219d74")) {
#                     Plotly.newPlot(
#                         '9cc35119-f664-40c9-b853-ea0198219d74',
# ...
